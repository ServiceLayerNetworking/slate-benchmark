# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('rps.csv', header=None)
df
# 7,1,SOURCE,sslateingress,SOURCE,sslateingress@POST@/cart,XXXX,us-west-1,87,89,0.9775280898876404
plt.plot(df[df[7]=="us-west-1"][8], label = "us-west-1")
plt.plot(df[df[7]=="us-east-1"][8], label = "us-east-1")
plt.legend()
