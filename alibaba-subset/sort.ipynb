# %%
# Loaded variable 'df' from URI: /users/gangmuk/projects/slate-benchmark/alibaba-subset/coef.csv
import pandas as pd
df = pd.read_csv(r'/users/gangmuk/projects/slate-benchmark/alibaba-subset/coef.csv')

# %%
df = df[df["feature"]!="intercept"]
df.sort_values(by=["value"], ascending=False, inplace=True)
df
# Out:
#          svc_name                   endpoint                    feature  \
# 46         dbd1b5         dbd1b5@POST@/heavy         dbd1b5@POST@/heavy
# 62          sd03b          sd03b@POST@/heavy          sd03b@POST@/heavy
# 38         db2af0         db2af0@POST@/heavy         db2af0@POST@/heavy
# 42         db3dd1         db3dd1@POST@/heavy         db3dd1@POST@/heavy
# 58         db10bb         db10bb@POST@/heavy         db10bb@POST@/heavy
# 68          s6f83          s6f83@POST@/heavy          s6f83@POST@/heavy
# 44          s222f          s222f@POST@/heavy          s222f@POST@/heavy
# 48          saaee          saaee@POST@/heavy          saaee@POST@/heavy
# 20          s6f83          s6f83@POST@/light          s6f83@POST@/light
# 70  sslateingress  sslateingress@POST@/heavy  sslateingress@POST@/heavy
# 6   sslateingress  sslateingress@POST@/light  sslateingress@POST@/light
# 10          s222f          s222f@POST@/light          s222f@POST@/light
# ...
