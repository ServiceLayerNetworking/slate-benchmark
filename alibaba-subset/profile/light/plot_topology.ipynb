# %%
import graphviz

# Create a new directed graph
graph = graphviz.Digraph()

# Example graph structure with nodes and edges
graph.edge("sslateingress", "s6f83")

edges = {
    "s6f83": {"saaee", "mc9653", "s23bd", "mc39aa", "mcd3a0", "mcbbb9", "mcde6d", "s4dd6", 
              "mc676c", "s222f", "mc01d6", "s6190", "sd03b", "mc2efe", "mc37e7", "s0696"},
    "saaee": {"db2af0", "mc660d", "mc59ee"},
    "s4dd6": {"s2387"},
    "s222f": {"db3dd1", "mc676c", "mc46a6", "mc01d6"},
    "sd03b": {"sb08b", "dbd1b5", "mc12c6", "mcd096", "mcc324", "db10bb"},
    "s0696": {"mc22fa", "db37c2", "db80f6", "mc2dd6"},
    "s2387": {"mcfb47"},
    "sb08b": {"s6b3d", "sda5a", "s7325", "s69e8"},
    "s6b3d": {"s598a", "s379e", "s30a8"},
    "sda5a": {"s69bc", "s3557", "s2be3", "sfd4d", "s8110"},
    "s69e8": {"s8fc3"},
    "s30a8": {"mcc964"}
}

# edges = {'s0': ['s4185d5a6', 's798a961f', 'sacd3486d'], 's4185d5a6': ['s994176cb', 'sc7465b49', 's0fda2e9e'], 's798a961f': [], 'sacd3486d': [], 's994176cb': [], 'sc7465b49': [], 's0fda2e9e': []}
# Add the edges to the graph
for node, children in edges.items():
    for child in children:
        graph.edge(node, child)

# Render the graph to a file (e.g., 'graph_output') and return the filename
filename = "graph_output"
graph.render(filename, format='png', cleanup=False)  # You can also use 'pdf', 'svg', etc.

# Display the rendered graph
graph

# %%
ep_str_callgraph_table = {'saaee@POST@/heavy': ['db2af0@POST@/heavy', 'mc59ee@POST@/heavy', 'mc660d@POST@/heavy'], 'mc46a6@POST@/heavy': [], 's222f@POST@/heavy': ['db3dd1@POST@/heavy', 'mc01d6@POST@/heavy', 'mc46a6@POST@/heavy', 'mc676c@POST@/heavy'], 'sd03b@POST@/heavy': ['db10bb@POST@/heavy', 'dbd1b5@POST@/heavy', 'mc12c6@POST@/heavy', 'mcc324@POST@/heavy', 'mcd096@POST@/heavy'], 'db10bb@POST@/heavy': [], 'sslateingress@POST@/heavy': ['s6f83@POST@/heavy'], 'mc59ee@POST@/heavy': [], 's6f83@POST@/heavy': ['mc9653@POST@/heavy', 's222f@POST@/heavy', 's4dd6@POST@/heavy', 'saaee@POST@/heavy'], 's4dd6@POST@/heavy': ['sd03b@POST@/heavy'], 'mc660d@POST@/heavy': [], 'mc676c@POST@/heavy': [], 'mc9653@POST@/heavy': [], 'mcc324@POST@/heavy': [], 'mc01d6@POST@/heavy': [], 'mcd096@POST@/heavy': [], 'mc12c6@POST@/heavy': [], 'db2af0@POST@/heavy': [], 'dbd1b5@POST@/heavy': [], 'db3dd1@POST@/heavy': []}

def graphviz_plot(ep_str_callgraph_table):
    graph = graphviz.Digraph()
    graph.attr('node', fontsize='8', height='0.2', width='0.2')  # Small font and node size
    graph.attr('edge', fontsize='8')  # Smaller edge label font
    for node, children in ep_str_callgraph_table.items():
        for child in children:
            graph.edge(node, child)
    graph.render("graph_output", format='pdf', cleanup=True)  # You can use 'pdf', 'svg', etc.
    return graph
graphviz_plot(ep_str_callgraph_table)
